# %%
# !git add portfolio.ipynb

# %%
# !git commit -m "Add portfolio notebook"

# %%
print("Cartogis portfolio of Lauri Levomäki")

# %% [markdown]
# TESTI TESTI TESTI

# %%
print("KOKEILUA")

# %%
# !pip install geopandas
# !pip install osmnx
# !pip install contextily
 

# install libraries

# !pip install folium 
# !pip install branca

## The story telling part start here:
# !pip install rasterio 

# !pip install mapclassify

# !pip install pysal
# Out:
# Requirement already satisfied: geopandas in c:\users\lauri\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (1.24.3)
# Requirement already satisfied: packaging in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\lauri\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: osmnx in c:\users\lauri\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: geopandas>=0.12 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (0.14.4)
# Requirement already satisfied: networkx>=2.5 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (3.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (1.24.3)
# Requirement already satisfied: pandas>=1.1 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (2.0.3)
# Requirement already satisfied: requests>=2.27 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in c:\users\lauri\anaconda3\lib\site-packages (from osmnx) (2.0.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas>=0.12->osmnx) (1.9.6)
# Requirement already satisfied: packaging in c:\users\lauri\anaconda3\lib\site-packages (from geopandas>=0.12->osmnx) (23.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.1->osmnx) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=1.1->osmnx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2.27->osmnx) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (22.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: colorama in c:\users\lauri\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas>=0.12->osmnx) (0.4.6)
# Requirement already satisfied: contextily in c:\users\lauri\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: geopy in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (3.7.2)
# Requirement already satisfied: mercantile in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (10.2.0)
# Requirement already satisfied: rasterio in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (1.3.10)
# Requirement already satisfied: requests in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (1.2.0)
# Requirement already satisfied: xyzservices in c:\users\lauri\anaconda3\lib\site-packages (from contextily) (2022.9.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\lauri\anaconda3\lib\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in c:\users\lauri\anaconda3\lib\site-packages (from mercantile->contextily) (8.0.4)
# Requirement already satisfied: affine in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (22.1.0)
# Requirement already satisfied: certifi in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (2024.2.2)
# Requirement already satisfied: cligj>=0.5 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->contextily) (68.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lauri\anaconda3\lib\site-packages (from requests->contextily) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lauri\anaconda3\lib\site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lauri\anaconda3\lib\site-packages (from requests->contextily) (1.26.16)
# Requirement already satisfied: colorama in c:\users\lauri\anaconda3\lib\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lauri\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Requirement already satisfied: folium in c:\users\lauri\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\lauri\anaconda3\lib\site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lauri\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\lauri\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\lauri\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\lauri\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lauri\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lauri\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lauri\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lauri\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lauri\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Requirement already satisfied: branca in c:\users\lauri\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: jinja2>=3 in c:\users\lauri\anaconda3\lib\site-packages (from branca) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lauri\anaconda3\lib\site-packages (from jinja2>=3->branca) (2.1.1)
# Requirement already satisfied: rasterio in c:\users\lauri\anaconda3\lib\site-packages (1.3.10)
# Requirement already satisfied: affine in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (22.1.0)
# Requirement already satisfied: certifi in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (1.24.3)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\lauri\anaconda3\lib\site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: colorama in c:\users\lauri\anaconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\lauri\anaconda3\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: mapclassify in c:\users\lauri\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify) (3.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify) (1.24.3)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify) (1.3.0)
# Requirement already satisfied: scipy>=1.8 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lauri\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lauri\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lauri\anaconda3\lib\site-packages (from scikit-learn>=1.0->mapclassify) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\lauri\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# Requirement already satisfied: pysal in c:\users\lauri\anaconda3\lib\site-packages (24.1)
# Requirement already satisfied: libpysal>=4.6.2 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (4.10)
# Requirement already satisfied: access>=1.1.8 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.5.1)
# Requirement already satisfied: giddy>=2.3.3 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.3.5)
# Requirement already satisfied: inequality>=1.0.0 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.0.1)
# Requirement already satisfied: pointpats>=2.2.0 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.4.0)
# Requirement already satisfied: segregation>=2.3.1 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.5)
# Requirement already satisfied: spaghetti>=1.6.6 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.1.2 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.2.1)
# Requirement already satisfied: momepy>=0.5.3 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (0.7.0)
# Requirement already satisfied: spglm>=1.0.8 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.0.7)
# Requirement already satisfied: spreg>=1.2.4 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (0.11.2)
# Requirement already satisfied: mapclassify>=2.4.3 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.4.1 in c:\users\lauri\anaconda3\lib\site-packages (from pysal) (0.6.0)
# Requirement already satisfied: geopandas in c:\users\lauri\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (0.14.4)
# Requirement already satisfied: numpy>=1.3 in c:\users\lauri\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (1.24.3)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\lauri\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (2.0.3)
# Requirement already satisfied: requests>=2 in c:\users\lauri\anaconda3\lib\site-packages (from access>=1.1.8->pysal) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\lauri\anaconda3\lib\site-packages (from esda>=2.4.1->pysal) (1.3.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\lauri\anaconda3\lib\site-packages (from esda>=2.4.1->pysal) (1.11.1)
# Requirement already satisfied: quantecon>=0.4.7 in c:\users\lauri\anaconda3\lib\site-packages (from giddy>=2.3.3->pysal) (0.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\lauri\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (4.12.2)
# Requirement already satisfied: packaging>=22 in c:\users\lauri\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (23.1)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\lauri\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (3.10.0)
# Requirement already satisfied: shapely>=2.0.1 in c:\users\lauri\anaconda3\lib\site-packages (from libpysal>=4.6.2->pysal) (2.0.4)
# Requirement already satisfied: networkx>=2.7 in c:\users\lauri\anaconda3\lib\site-packages (from mapclassify>=2.4.3->pysal) (3.1)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\lauri\anaconda3\lib\site-packages (from momepy>=0.5.3->pysal) (4.65.0)
# Requirement already satisfied: matplotlib in c:\users\lauri\anaconda3\lib\site-packages (from pointpats>=2.2.0->pysal) (3.7.2)
# Requirement already satisfied: deprecation in c:\users\lauri\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (2.1.0)
# Requirement already satisfied: joblib in c:\users\lauri\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (1.2.0)
# Requirement already satisfied: seaborn in c:\users\lauri\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (0.12.2)
# Requirement already satisfied: numba in c:\users\lauri\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (0.57.1)
# Requirement already satisfied: pyproj>=3 in c:\users\lauri\anaconda3\lib\site-packages (from segregation>=2.3.1->pysal) (3.6.1)
# Requirement already satisfied: rtree>=1.0 in c:\users\lauri\anaconda3\lib\site-packages (from spaghetti>=1.6.6->pysal) (1.0.1)
# Requirement already satisfied: pulp>=2.7 in c:\users\lauri\anaconda3\lib\site-packages (from spopt>=0.4.1->pysal) (2.8.0)
# Requirement already satisfied: rasterio in c:\users\lauri\anaconda3\lib\site-packages (from tobler>=0.8.2->pysal) (1.3.10)
# Requirement already satisfied: statsmodels in c:\users\lauri\anaconda3\lib\site-packages (from tobler>=0.8.2->pysal) (0.14.0)
# Requirement already satisfied: rasterstats in c:\users\lauri\anaconda3\lib\site-packages (from tobler>=0.8.2->pysal) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lauri\anaconda3\lib\site-packages (from beautifulsoup4>=4.10->libpysal>=4.6.2->pysal) (2.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\lauri\anaconda3\lib\site-packages (from geopandas->access>=1.1.8->pysal) (1.9.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lauri\anaconda3\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2023.3)
# Requirement already satisfied: certifi in c:\users\lauri\anaconda3\lib\site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2024.2.2)
# Requirement already satisfied: sympy in c:\users\lauri\anaconda3\lib\site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.11.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\lauri\anaconda3\lib\site-packages (from numba->segregation>=2.3.1->pysal) (0.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lauri\anaconda3\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (1.26.16)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lauri\anaconda3\lib\site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal) (2.2.0)
# Requirement already satisfied: colorama in c:\users\lauri\anaconda3\lib\site-packages (from tqdm>=4.63.0->momepy>=0.5.3->pysal) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lauri\anaconda3\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.0.9)
# Requirement already satisfied: affine in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (2.4.0)
# Requirement already satisfied: attrs in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (22.1.0)
# Requirement already satisfied: click>=4.0 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\lauri\anaconda3\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (68.0.0)
# Requirement already satisfied: simplejson in c:\users\lauri\anaconda3\lib\site-packages (from rasterstats->tobler>=0.8.2->pysal) (3.19.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\lauri\anaconda3\lib\site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.3)
# Requirement already satisfied: six in c:\users\lauri\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lauri\anaconda3\lib\site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.3.0)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# muista: https://hri.fi/data/fi/dataset/vaestotietoruudukko

# Step 1: Load Data
helsinki_grid = gpd.read_file('data/vaestotieto/Vaestotietoruudukko_2022.shp')

helsinki_grid = helsinki_grid.to_crs(epsg=3879)  # Change the projection to Web Mercator (EPSG:3857)

# Define population density bins
density_bins = [0, 500, 1000, 1500, 2000, 2500]  # Define your own population density bins here

# Define population density bin labels
density_labels = ['< 500', '500 - 1000', '1000 - 1500', '1500 - 2000', '2000 - 2500']

# Assign each cell to a population density bin
helsinki_grid['density_bin'] = pd.cut(helsinki_grid['ASUKKAITA'], bins=density_bins, labels=density_labels)

# Extract the boundaries of each grid cell
cell_boundaries = helsinki_grid.boundary

# Plot the thematic map with different colors for each population density bin and narrower cell boundaries
fig, ax = plt.subplots(figsize=(12, 6))

cell_boundaries.plot(ax=ax, color='black', linewidth=0.1)  # Plot cell boundaries with narrower lines and white color
helsinki_grid.plot(column='density_bin', ax=ax, legend=True, cmap='Blues', linewidth=0.1,
                   legend_kwds={'title': 'Population/\n250x250m', 'loc': 'upper right', 'bbox_to_anchor': (0.92, 0.3)})
ax.axis('off')  # Turn off the axis
plt.title('POPULATION DENSITY IN HELSINKI REGION 2022', fontsize=15, fontweight='bold', color='blue', pad=30)  # Use Arial font and set title color to white

# Add the data source text in the bottom left corner with blue color
plt.text(0.03, 0.06, 'Source: Helsinki Region Infoshare', transform=ax.transAxes, fontsize=9, color='blue')

# Save the plot as a PNG file
plt.savefig('population_density_helsinki.png', bbox_inches='tight')

plt.show()

# %%
import geopandas as gpd
import pathlib
import osmnx
import contextily
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Path to our Experience data from Helsinki
NOTEBOOK_PATH = pathlib.Path().resolve()

# We will export the final map here,
# let’s also prepare an output directory for it:
DATA_DIRECTORY = NOTEBOOK_PATH / 'data'
MAP_DIRECTORY = NOTEBOOK_PATH / "MyMap_happypoints"
MAP_DIRECTORY.mkdir(exist_ok=True)
file_path = DATA_DIRECTORY / 'happypoints/happy_points.shp'

# Read the data as a GeoDataFrame named exp_places
exp_places = gpd.read_file(file_path)
print(exp_places.head(1))
print(f"Number of rows in our dataset: {len(exp_places)}")

# Print the first row of the dataset to see a sample of the data
print(exp_places.head(1))

# Print the column names
print("Columns in the dataset:", exp_places.columns)

# Print a summary of the GeoDataFrame to get more details about the data
print(exp_places.info())

PLACE_NAME = "Helsinki, Finland"
helsinki_area = osmnx.geocode_to_gdf(PLACE_NAME)

# Get the polygon to the same CRS as original data
helsinki_area = helsinki_area.to_crs(exp_places.crs)

# Ensure CRS match
assert exp_places.crs == helsinki_area.crs, "CRS do not match"

# Spatial join to extract points within the polygon
points_in_helsinki = gpd.sjoin(exp_places, helsinki_area, how="inner", predicate='within')

# Adding a basemap
points_to_vis = points_in_helsinki.to_crs("EPSG:3857")

# Create the figure and axis objects
fig, ax = plt.subplots()

# Fill the outer area with a neutral color
fig.patch.set_facecolor('#ADD8E6')

# Plotting with a larger marker size and contrasting color
points_to_vis.plot(ax=ax, markersize=8, color='blue', legend=True, alpha=0.6, edgecolor='black')

# Adding the OpenStreetMap Carto basemap
contextily.add_basemap(ax, source=contextily.providers.CartoDB.Positron)

# Add main title
main_title_text = 'Where 55-75 Year Olds Feel Happy in Helsinki'
ax.set_title(main_title_text, fontsize=15, weight='bold')

# Add data source attribution
attribution_text = "Data source: SoftGIS Group (Aalto University)"
ax.text(0.99, 0.002, attribution_text, transform=ax.transAxes, fontsize=7,
        verticalalignment='bottom', horizontalalignment='right', color='black', alpha=0.7)

# Add second title styled similarly to the main title
second_title_text = "Data collected in 2015"
ax.text(0.5, -0.05, second_title_text, transform=ax.transAxes, fontsize=10,
        verticalalignment='bottom', horizontalalignment='center', color='black', alpha=0.7, fontweight='bold')

# Remove ticks and axis labels
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('')
ax.set_ylabel('')

# Set this to off if you want to remove the frame
ax.axis('on')

# Add a black frame
rect = Rectangle((0, 0), 1, 1, transform=ax.transAxes, linewidth=2, edgecolor='black', facecolor='none')
ax.add_patch(rect)

# Adjust figure size and modify only left and right margins
fig.set_size_inches(12, 6)  # Increase width only
fig.subplots_adjust(left=0.1, right=0.9, top=0.95, bottom=0.05)  # Keep top and bottom as they were

# Save the map
map_file_path = MAP_DIRECTORY / 'happy_places_map.png'
fig.savefig(map_file_path, bbox_inches='tight', pad_inches=0.1)
print(f"Map saved to: {map_file_path}")

# %%
# install libraries
# !pip install geopandas
# !pip install folium 
# !pip install branca

# %%
# import libraries
import geopandas as gpd
import folium
from folium import Choropleth
import os

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Define the path to the directory containing the shapefile
shapefile_dir = 'ilmanlaatu_shape/'

# Choose the year to visualize
year = 2023
filename = f'typpidioksidin_vuosikeskiarvot_{year}.shp'
filepath = os.path.join(shapefile_dir, filename)

# Load the shapefile into a GeoDataFrame
gdf = gpd.read_file(filepath)

# Ensure GeoDataFrame is in WGS84 (EPSG:4326)
if gdf.crs != 'EPSG:4326':
    gdf = gdf.to_crs(epsg=4326)

# Plot the GeoDataFrame
gdf.plot(figsize=(10, 10))
plt.title('Air Quality Data')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import os
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox

# Load air quality data into a GeoDataFrame
shapefile_dir = 'ilmanlaatu_shape/'
filename = 'typpidioksidin_vuosikeskiarvot_2023.shp'
filepath = os.path.join(shapefile_dir, filename)
air_quality_gdf = gpd.read_file(filepath)

# Filter data for the year 2023
air_quality_gdf = air_quality_gdf[air_quality_gdf['Vuosi'] == 2023]

# Geocode Helsinki boundaries using OSMnx
PLACE_NAME = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(PLACE_NAME)

# Reproject Helsinki area to match the CRS of the air quality data
helsinki_area = helsinki_area.to_crs(air_quality_gdf.crs)

# Clip air quality data to Helsinki area
air_quality_gdf = gpd.clip(air_quality_gdf, helsinki_area)

# Reproject air quality data and Helsinki area to EPSG:3857 for basemap compatibility
air_quality_gdf = air_quality_gdf.to_crs(epsg=3857)
helsinki_area = helsinki_area.to_crs(epsg=3857)

# Plotting with colors based on the 'NO2' column
ax = air_quality_gdf.plot(
    figsize=(12, 8),
    column="NO2",
    scheme="NaturalBreaks",
    cmap="viridis_r",
    linewidth=1,
    alpha=1.0,  # Adjusted alpha value to make the basemap more visible
    legend=True,
    legend_kwds={"title": "Mean NO2", "loc": "lower right"}
)
###########

# Adding a basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, alpha=0.6, attribution="Data: Helsinki Region Infoshare ; OSM")

# Add legend title
cbar = ax.get_figure().get_axes()[1]  # Get the colorbar axis
cbar.set_ylabel("NO2")  # Set the label for the colorbar

# Remove ticks and axis labels
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlabel('')
ax.set_ylabel('')

# Set this to off if you want to remove the frame
ax.axis('on')

# Adjust figure size to accommodate the legend, if necessary
fig = ax.figure
fig.set_size_inches(8, 6)
fig.tight_layout()

# Set the axis limits to ensure the map is centered and zoom out a bit
zoom_out_factor = 1.3  # Adjust this factor to zoom out more or less
ax.set_xlim(x_center - (x_extent / 2) * zoom_out_factor, x_center + (x_extent / 2) * zoom_out_factor)
ax.set_ylim(y_center - (y_extent / 2) * zoom_out_factor, y_center + (y_extent / 2) * zoom_out_factor)

# Adjust layout
plt.tight_layout()

# Add title
plt.title('Air quality in Helsinki (2023)', fontdict={'fontsize': '16', 'fontweight': '3'})

plt.show()

# %%
#3 GRID MAP 2015
## TAMA TOIMII
## MUUTA TIEDOT (otsikot jne, source)
import os
import geopandas as gpd
from shapely.geometry import Polygon, Point
import numpy as np
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
from mapclassify import UserDefined

# Load air quality data into a GeoDataFrame
shapefile_dir = 'ilmanlaatu_shape/'
filename = 'typpidioksidin_vuosikeskiarvot_2015.shp'
filepath = os.path.join(shapefile_dir, filename)
air_quality_gdf = gpd.read_file(filepath)

# Filter data for the year 2023
air_quality_gdf = air_quality_gdf[air_quality_gdf['Vuosi'] == 2015]

# Print the first row of the dataset to see a sample of the data
print(air_quality_gdf.head(1))

# Print the column names
print("Columns in the dataset:", air_quality_gdf.columns)

# Print a summary of the GeoDataFrame to get more details about the data
print(air_quality_gdf.info())

# Geocode Helsinki boundaries using OSMnx
PLACE_NAME = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(PLACE_NAME)

# Check and print CRS of both datasets
print("Air quality data CRS:", air_quality_gdf.crs)
print("Helsinki area CRS:", helsinki_area.crs)

# Reproject Helsinki area to match the CRS of the air quality data
helsinki_area = helsinki_area.to_crs(air_quality_gdf.crs)

# Ensure CRS match
assert air_quality_gdf.crs == helsinki_area.crs, "CRS do not match"

# Clip air quality data to Helsinki area
air_quality_gdf = gpd.clip(air_quality_gdf, helsinki_area)

# Determine the bounds of the air quality data
minx, miny, maxx, maxy = air_quality_gdf.total_bounds

# Grid dimensions (in meters)
grid_height = 250
grid_width = 250

# Generate the x and y coordinates for the grid
x_coords = np.arange(minx, maxx + grid_width, grid_width)
y_coords = np.arange(miny, maxy + grid_height, grid_height)

# Initialize a list to hold the grid polygons
grid_polygons = []

for x in x_coords:
    for y in y_coords:
        # Define the polygon for each cell
        polygon = Polygon([(x, y), (x+grid_width, y), (x+grid_width, y+grid_height), (x, y+grid_height)])
        grid_polygons.append(polygon)

# Create a GeoDataFrame from the grid polygons
grid_gdf = gpd.GeoDataFrame({'geometry': grid_polygons}, crs=air_quality_gdf.crs)

# Perform the spatial join
joined_gdf = gpd.sjoin(grid_gdf, air_quality_gdf, how="inner", predicate="intersects")

# Aggregate NO2 values by grid cell
mean_no2_df = joined_gdf.groupby(joined_gdf.index)['NO2'].mean()

# Join the aggregated NO2 values back to the grid GeoDataFrame
grid_with_no2 = grid_gdf.join(mean_no2_df, how='inner')

# Reproject grid_with_no2 to EPSG:3857 for basemap compatibility
grid_with_no2 = grid_with_no2.to_crs(epsg=3857)

# Reproject helsinki_area to EPSG:3857 for basemap compatibility
helsinki_area = helsinki_area.to_crs(epsg=3857)

#Plot the grid with NO2 values

#Visualize
ax = grid_with_no2.plot(
    figsize=(12, 8),

    column="NO2",
    scheme="NaturalBreaks",
    cmap="viridis_r",
    linewidth=1,
    alpha=1.0,

    legend=True,
    legend_kwds={"title": "Perception", "loc": "lower right"}
)


# Remove axis
ax.set_axis_off()
plt.title('Mean NO2 values in Helsinki (2020)', 
    fontdict={'fontsize': '20', 'fontweight': '7'},
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
         )

# basemap
contextily.add_basemap(
    ax,
    source=contextily.providers.CartoDB.Positron, alpha=1.0,  # Increased alpha value for basemap visibility
    attribution=("Data: Helsinki Region Infoshare; OSM")
)

# Add a scale bar with AnchoredSizeBar
fontprops = fm.FontProperties(size=10)
scalebar = AnchoredSizeBar(ax.transData,
                           1000,  # Length of the bar in data units
                           '1 km',  # Label for the scale bar
                           'lower center',  # Location of the scale bar
                           pad=0.1,
                           color='black',
                           frameon=False,
                           size_vertical=1,
                           fontproperties=fontprops)

ax.add_artist(scalebar)

# Add Helsinki boundaries with green edges
helsinki_area.boundary.plot(ax=ax, edgecolor="green", linewidth=1)

# Calculate the extent and center of the grid_with_no2 data
minx, miny, maxx, maxy = grid_with_no2.total_bounds
x_center = (minx + maxx) / 2
y_center = (miny + maxy) / 2
x_extent = maxx - minx
y_extent = maxy - miny
margin = 0.1  # Adjust this value to add margin around the map

# Set the axis limits to ensure the map is centered and zoom out a bit
zoom_out_factor = 1.3  # Adjust this factor to zoom out more or less
ax.set_xlim(x_center - (x_extent / 2) * zoom_out_factor, x_center + (x_extent / 2) * zoom_out_factor)
ax.set_ylim(y_center - (y_extent / 2) * zoom_out_factor, y_center + (y_extent / 2) * zoom_out_factor)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
#3 GRID MAP 2020
## TAMA TOIMII
## MUUTA TIEDOT (otsikot jne, source)
import os
import geopandas as gpd
from shapely.geometry import Polygon, Point
import numpy as np
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
from mapclassify import UserDefined

# Load air quality data into a GeoDataFrame
shapefile_dir = 'ilmanlaatu_shape/'
filename = 'typpidioksidin_vuosikeskiarvot_2020.shp'
filepath = os.path.join(shapefile_dir, filename)
air_quality_gdf = gpd.read_file(filepath)

# Filter data for the year 2023
air_quality_gdf = air_quality_gdf[air_quality_gdf['Vuosi'] == 2020]

# Print the first row of the dataset to see a sample of the data
print(air_quality_gdf.head(1))

# Print the column names
print("Columns in the dataset:", air_quality_gdf.columns)

# Print a summary of the GeoDataFrame to get more details about the data
print(air_quality_gdf.info())

# Geocode Helsinki boundaries using OSMnx
PLACE_NAME = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(PLACE_NAME)

# Check and print CRS of both datasets
print("Air quality data CRS:", air_quality_gdf.crs)
print("Helsinki area CRS:", helsinki_area.crs)

# Reproject Helsinki area to match the CRS of the air quality data
helsinki_area = helsinki_area.to_crs(air_quality_gdf.crs)

# Ensure CRS match
assert air_quality_gdf.crs == helsinki_area.crs, "CRS do not match"

# Clip air quality data to Helsinki area
air_quality_gdf = gpd.clip(air_quality_gdf, helsinki_area)

# Determine the bounds of the air quality data
minx, miny, maxx, maxy = air_quality_gdf.total_bounds

# Grid dimensions (in meters)
grid_height = 250
grid_width = 250

# Generate the x and y coordinates for the grid
x_coords = np.arange(minx, maxx + grid_width, grid_width)
y_coords = np.arange(miny, maxy + grid_height, grid_height)

# Initialize a list to hold the grid polygons
grid_polygons = []

for x in x_coords:
    for y in y_coords:
        # Define the polygon for each cell
        polygon = Polygon([(x, y), (x+grid_width, y), (x+grid_width, y+grid_height), (x, y+grid_height)])
        grid_polygons.append(polygon)

# Create a GeoDataFrame from the grid polygons
grid_gdf = gpd.GeoDataFrame({'geometry': grid_polygons}, crs=air_quality_gdf.crs)

# Perform the spatial join
joined_gdf = gpd.sjoin(grid_gdf, air_quality_gdf, how="inner", predicate="intersects")

# Aggregate NO2 values by grid cell
mean_no2_df = joined_gdf.groupby(joined_gdf.index)['NO2'].mean()

# Join the aggregated NO2 values back to the grid GeoDataFrame
grid_with_no2 = grid_gdf.join(mean_no2_df, how='inner')

# Reproject grid_with_no2 to EPSG:3857 for basemap compatibility
grid_with_no2 = grid_with_no2.to_crs(epsg=3857)

# Reproject helsinki_area to EPSG:3857 for basemap compatibility
helsinki_area = helsinki_area.to_crs(epsg=3857)

#Plot the grid with NO2 values

#Visualize
ax = grid_with_no2.plot(
    figsize=(12, 8),

    column="NO2",
    scheme="NaturalBreaks",
    cmap="viridis_r",
    linewidth=1,
    alpha=1.0,

    legend=True,
    legend_kwds={"title": "Perception", "loc": "lower right"}
)


# Remove axis
ax.set_axis_off()
plt.title('Mean NO2 values in Helsinki (2020)', 
    fontdict={'fontsize': '20', 'fontweight': '7'},
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
         )

# basemap
contextily.add_basemap(
    ax,
    source=contextily.providers.CartoDB.Positron, alpha=1.0,  # Increased alpha value for basemap visibility
    attribution=("Data: Helsinki Region Infoshare; OSM")
)

# Add a scale bar with AnchoredSizeBar
fontprops = fm.FontProperties(size=10)
scalebar = AnchoredSizeBar(ax.transData,
                           1000,  # Length of the bar in data units
                           '1 km',  # Label for the scale bar
                           'lower center',  # Location of the scale bar
                           pad=0.1,
                           color='black',
                           frameon=False,
                           size_vertical=1,
                           fontproperties=fontprops)

ax.add_artist(scalebar)

# Add Helsinki boundaries with green edges
helsinki_area.boundary.plot(ax=ax, edgecolor="green", linewidth=1)

# Calculate the extent and center of the grid_with_no2 data
minx, miny, maxx, maxy = grid_with_no2.total_bounds
x_center = (minx + maxx) / 2
y_center = (miny + maxy) / 2
x_extent = maxx - minx
y_extent = maxy - miny
margin = 0.1  # Adjust this value to add margin around the map

# Set the axis limits to ensure the map is centered and zoom out a bit
zoom_out_factor = 1.5  # Adjust this factor to zoom out more or less
ax.set_xlim(x_center - (x_extent / 2) * zoom_out_factor, x_center + (x_extent / 2) * zoom_out_factor)
ax.set_ylim(y_center - (y_extent / 2) * zoom_out_factor, y_center + (y_extent / 2) * zoom_out_factor)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
#3 GRID MAP
## TAMA TOIMII
## MUUTA TIEDOT (otsikot jne, source)
import os
import geopandas as gpd
from shapely.geometry import Polygon, Point
import numpy as np
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
from mapclassify import UserDefined

# Load air quality data into a GeoDataFrame
shapefile_dir = 'ilmanlaatu_shape/'
filename = 'typpidioksidin_vuosikeskiarvot_2023.shp'
filepath = os.path.join(shapefile_dir, filename)
air_quality_gdf = gpd.read_file(filepath)

# Filter data for the year 2023
air_quality_gdf = air_quality_gdf[air_quality_gdf['Vuosi'] == 2023]

# Print the first row of the dataset to see a sample of the data
print(air_quality_gdf.head(1))

# Print the column names
print("Columns in the dataset:", air_quality_gdf.columns)

# Print a summary of the GeoDataFrame to get more details about the data
print(air_quality_gdf.info())

# Geocode Helsinki boundaries using OSMnx
PLACE_NAME = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(PLACE_NAME)

# Check and print CRS of both datasets
print("Air quality data CRS:", air_quality_gdf.crs)
print("Helsinki area CRS:", helsinki_area.crs)

# Reproject Helsinki area to match the CRS of the air quality data
helsinki_area = helsinki_area.to_crs(air_quality_gdf.crs)

# Ensure CRS match
assert air_quality_gdf.crs == helsinki_area.crs, "CRS do not match"

# Clip air quality data to Helsinki area
air_quality_gdf = gpd.clip(air_quality_gdf, helsinki_area)

# Determine the bounds of the air quality data
minx, miny, maxx, maxy = air_quality_gdf.total_bounds

# Grid dimensions (in meters)
grid_height = 250
grid_width = 250

# Generate the x and y coordinates for the grid
x_coords = np.arange(minx, maxx + grid_width, grid_width)
y_coords = np.arange(miny, maxy + grid_height, grid_height)

# Initialize a list to hold the grid polygons
grid_polygons = []

for x in x_coords:
    for y in y_coords:
        # Define the polygon for each cell
        polygon = Polygon([(x, y), (x+grid_width, y), (x+grid_width, y+grid_height), (x, y+grid_height)])
        grid_polygons.append(polygon)

# Create a GeoDataFrame from the grid polygons
grid_gdf = gpd.GeoDataFrame({'geometry': grid_polygons}, crs=air_quality_gdf.crs)

# Perform the spatial join
joined_gdf = gpd.sjoin(grid_gdf, air_quality_gdf, how="inner", predicate="intersects")

# Aggregate NO2 values by grid cell
mean_no2_df = joined_gdf.groupby(joined_gdf.index)['NO2'].mean()

# Join the aggregated NO2 values back to the grid GeoDataFrame
grid_with_no2 = grid_gdf.join(mean_no2_df, how='inner')

# Reproject grid_with_no2 to EPSG:3857 for basemap compatibility
grid_with_no2 = grid_with_no2.to_crs(epsg=3857)

# Reproject helsinki_area to EPSG:3857 for basemap compatibility
helsinki_area = helsinki_area.to_crs(epsg=3857)

#Visualize
ax = grid_with_no2.plot(
    figsize=(12, 8),
    column="NO2",
    scheme="NaturalBreaks",
    cmap="viridis_r",
    linewidth=1,
    alpha=1.0,

    legend=True,
    legend_kwds={"title": "Perception", "loc": "lower right"}
)


# Remove axis
ax.set_axis_off()
plt.title('Mean NO2 values in Helsinki (2023)', 
    fontdict={'fontsize': '20', 'fontweight': '7'},
    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5')
         )

# basemap
contextily.add_basemap(
    ax,
    source=contextily.providers.CartoDB.Positron, alpha=1.0,  # Increased alpha value for basemap visibility
    attribution=("Data: Helsinki Region Infoshare; OSM")
)

# Add a scale bar with AnchoredSizeBar
fontprops = fm.FontProperties(size=10)
scalebar = AnchoredSizeBar(ax.transData,
                           1000,  # Length of the bar in data units
                           '1 km',  # Label for the scale bar
                           'lower center',  # Location of the scale bar
                           pad=0.1,
                           color='black',
                           frameon=False,
                           size_vertical=1,
                           fontproperties=fontprops)

ax.add_artist(scalebar)

# Add Helsinki boundaries with green edges
helsinki_area.boundary.plot(ax=ax, edgecolor="green", linewidth=1)

# Calculate the extent and center of the grid_with_no2 data
minx, miny, maxx, maxy = grid_with_no2.total_bounds
x_center = (minx + maxx) / 2
y_center = (miny + maxy) / 2
x_extent = maxx - minx
y_extent = maxy - miny
margin = 0.1  # Adjust this value to add margin around the map

# Set the axis limits to ensure the map is centered and zoom out a bit
zoom_out_factor = 1.3  # Adjust this factor to zoom out more or less
ax.set_xlim(x_center - (x_extent / 2) * zoom_out_factor, x_center + (x_extent / 2) * zoom_out_factor)
ax.set_ylim(y_center - (y_extent / 2) * zoom_out_factor, y_center + (y_extent / 2) * zoom_out_factor)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox

# Geocode Helsinki boundaries using OSMnx
PLACE_NAME = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(PLACE_NAME)

# Initialize a dictionary to store mean NO2 values for each year
mean_no2_values = {}

# Loop through each year
for year in range(2010, 2024):
    # Load the shapefile for the current year
    filepath = f"ilmanlaatu_shape/typpidioksidin_vuosikeskiarvot_{year}.shp"
    air_quality_gdf = gpd.read_file(filepath)
    
    # Ensure the air quality data and Helsinki boundary are in the same CRS
    air_quality_gdf = air_quality_gdf.to_crs(helsinki_area.crs)
    
    # Spatially join to keep only points within Helsinki boundary
    air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_area, how='intersection')
    
    # Extract year and NO2 columns
    extracted_data = air_quality_helsinki[['Vuosi', 'NO2']]
    
    # Convert NO2 column to numeric, coercing errors to NaN
    extracted_data['NO2'] = pd.to_numeric(extracted_data['NO2'], errors='coerce')
    
    # Calculate the mean NO2 value for the current year, excluding NaN values
    mean_no2 = extracted_data['NO2'].mean()
    
    # Store the mean NO2 value in the dictionary
    mean_no2_values[year] = mean_no2

# Convert the dictionary to a pandas Series
mean_no2_series = pd.Series(mean_no2_values)

print(mean_no2_series)

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Bar chart
plt.subplot(1, 2, 1)
mean_no2_series.plot(kind='bar', color='skyblue')
plt.xlabel('Year')
plt.ylabel('Mean NO2 Concentration')
plt.title('Average NO2 Concentration (2010 to 2023)')
plt.grid(True)

# Line chart
plt.subplot(1, 2, 2)
mean_no2_series.plot(kind='line', marker='o', color='green')
plt.xlabel('Year')
plt.ylabel('Mean NO2 Concentration')
plt.title('Temporal Trends in Mean NO2 Concentrations (2010 to 2023)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# saving the shape file
import osmnx as ox

# Geocode Helsinki boundaries using OSMnx
place_name = "Helsinki, Finland"
helsinki_area = ox.geocode_to_gdf(place_name)

# Save the boundaries to a shapefile
output_shapefile = "helsinki_boundary.shp"
helsinki_area.to_file(output_shapefile)

# Confirm the file path where the shapefile is saved
print(f"Shapefile saved to: {os.path.abspath(output_shapefile)}")

# %%
import geopandas as gpd
import pandas as pd
import folium

# Load Helsinki boundary data
helsinki_boundary = gpd.read_file("helsinki_boundary.shp")

# Load the CRS of air_quality_gdf
crs_air_quality = air_quality_gdf.crs

# Reproject helsinki_boundary to match the CRS of air_quality_gdf
helsinki_boundary = helsinki_boundary.to_crs(crs_air_quality)




# Initialize a list to store all data
all_data = []

# Loop through each year
for year in years:
    # Load the shapefile for the current year
    filepath = f"ilmanlaatu_shape/typpidioksidin_vuosikeskiarvot_{year}.shp"
    air_quality_gdf = gpd.read_file(filepath)
    
    # Apply spatial filter to extract only data within Helsinki boundaries
    air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
    
    # Transform CRS to EPSG:4326
    air_quality_helsinki = air_quality_helsinki.to_crs(epsg=4326)
    
    # Extract necessary columns: 'Vuosi', 'NO2', and the geometry for location
    extracted_data = air_quality_helsinki[['Vuosi', 'NO2', 'geometry']]
    
    # Ensure only data for the specific year is selected
    extracted_data = extracted_data[extracted_data['Vuosi'] == year]
    
    # Convert NO2 column to numeric, coercing errors to NaN
    extracted_data['NO2'] = pd.to_numeric(extracted_data['NO2'], errors='coerce')
    
    # Add the year column for reference
    extracted_data['Year'] = year
    
    # Append to the list
    all_data.append(extracted_data)

# Concatenate all data into a single GeoDataFrame
all_data_gdf = pd.concat(all_data, ignore_index=True)

# Create a Folium map centered on Helsinki
m = folium.Map(location=[60.1699, 24.9384], zoom_start=11)

# Add markers for each observation
for idx, row in all_data_gdf.iterrows():
    if pd.notnull(row['NO2']):
        folium.Marker(
            location=[row.geometry.y, row.geometry.x],
            popup=f"Year: {row['Year']}<br>NO2: {row['NO2']}",
            icon=folium.Icon(color='blue' if row['NO2'] < 20 else 'red')
        ).add_to(m)

# Save the map to an HTML file
m.save('air_quality_map_helsinki.html')

# Display the map (this will work in Jupyter Notebook)
m
# Out:
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# C:\Users\lauri\AppData\Local\Temp\ipykernel_4812\3410000148.py:27: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: PROJCS["ETRS89_ETRS_GK25FIN_2010",GEOGCS["ETRS89", ...
# Right CRS: EPSG:3879
#
#   air_quality_helsinki = gpd.overlay(air_quality_gdf, helsinki_boundary, how='intersection')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3faac7c8bb2e983b73beb58c76b727bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3faac7c8bb2e983b73beb58c76b727bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3faac7c8bb2e983b73beb58c76b727bd = L.map(
#                 &quot;map_3faac7c8bb2e983b73beb58c76b727bd&quot;,
#                 {
#                     center: [60.1699, 24.9384],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8f892da31987bddc5dd99750ad9e4d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a8f892da31987bddc5dd99750ad9e4d9.addTo(map_3faac7c8bb2e983b73beb58c76b727bd);
#
#
#             var marker_a5944199af2e822083afd02a61c91939 = L.marker(
#                 [60.187383796002614, 24.950598497713038],
#                 {}
#             ).addTo(map_3faac7c8bb2e983b73beb58c76b727bd);
#
#
#             var icon_0732f7b5ae5905887ebce93768f77954 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a5944199af2e822083afd02a61c91939.setIcon(icon_0732f7b5ae5905887ebce93768f77954);
#
#
#         var popup_4bb3eb5114b9b0122f5907b841c8db34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a933728e10e51f5fe2dfb0fa2afc2cee = $(`&lt;div id=&quot;html_a933728e10e51f5fe2dfb0fa2afc2cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2010&lt;br&gt;NO2: 23&lt;/div&gt;`)[0];
#                 popup_4bb3eb5114b9b0122f5907b841c8db34.setContent(html_a933728e10e51f5fe2dfb0fa2afc2cee);
#
#
#
#         marker_a5944199af2e822083afd02a61c91939.bindPopup(popup_4bb3eb5114b9b0122f5907b841c8db34)
#         ;
#
#
#
#
#             var marker_c419676210257e3786cf4c73a794225f = L.marker(
#                 [60.16964363824762, 24.939258641603235],
#                 {}
#             ).addTo(map_3faac7c8bb2e983b73beb58c76b727bd);
#
#
#             var icon_de92504adf69fd205c6ea2176fb5b950 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c419676210257e3786cf4c73a794225f.setIcon(icon_de92504adf69fd205c6ea2176fb5b950);
#
#
#         var popup_366f2be9633debdff460abf858a8e234 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80045f636dc6eaacd907cbc43ba1475d = $(`&lt;div id=&quot;html_80045f636dc6eaacd907cbc43ba1475d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2010&lt;br&gt;NO2: 41&lt;/div&gt;`)[0];
#                 popup_366f2be9633debdff460abf858a8e234.setContent(html_80045f636dc6eaacd907cbc43ba1475d);
#
#
#
#         marker_c419676210257e3786cf4c73a794225f.bindPopup(popup_366f2be9633debdff460abf858a8e234)
#         ;
#
#
#
#
#             var marker_3cc9bb40f71153c7b97d61471ed5da2a = L.marker(
#                 [60.22388323188184, 25.102521470001125],
#                 {}
#             ).addTo(map_3faac7c8bb2e983b73beb58c76b727bd);
#
#
#             var icon_0634b225f984a7effd2adf47a2e5bee6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3cc9bb40f71153c7b97d61471ed5da2a.setIcon(icon_0634b225f984a7effd2adf47a2e5bee6);
#
#
#         var popup_248a60c3fdc0f79f1750ce252bd887d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f5c2f37dea33189261ead27dc970587 = $(`&lt;div id=&quot;html_7f5c2f37dea33189261ead27dc970587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Year: 2010&lt;br&gt;NO2: 0&lt;/div&gt;`)[0];
#                 popup_248a60c3fdc0f79f1750ce252bd887d8.setContent(html_7f5c2f37dea33189261ead27dc970587);
#
#
#
#         marker_3cc9bb40f71153c7b97d61471ed5da2a.bindPopup(popup_248a60c3fdc0f79f1750ce252bd887d8)
#         ;
#
#
#
#
#             var marker_67ab57d05bce3c47a202ff6f2da05727 = L.marker(
#                 [60.193661904634055, 24.963928756155322],
#                 {}
#             ).addTo(map_3faac7c8bb2e983b73beb58c76b727bd);
#
#
#             var icon_d209c7d0861d17f6428ff8b0d37a6b48 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotat

# %%
# This push changes to Github page

# !git add .
# !git commit -m "Description of your changes"
# !git push origin main

# %%
# !git push origin main

# %%
#Bar diagram and line chart
